# %% [markdown]
# # DecoupleNet — LoveDA Validation
# Egitilmis modeli validation seti uzerinde degerlendirir (mIoU, F1, OA).

# %%
# 1. Drive bagla
from google.colab import drive
drive.mount('/content/drive')

# %%
# 2. Repoyu guncelle
import os
if os.path.exists('/content/DecoupleNet'):
    # !cd /content/DecoupleNet && git stash && git pull
else:
    # !cd /content && git clone https://github.com/myrisee/DecoupleNet.git

# %%
# 3. Gerekli kutuphaneler
import sys
sys.path.insert(0, '/content/DecoupleNet/segmentation')

# !pip install -q ttach albumentations timm antialiased_cnns addict

# %%
# 4. Validation calistir
# %cd /content/DecoupleNet/segmentation

# !python loveda_test.py \
  -c config/loveda/train_decouplenet_colab.py \
  -o fig_results/loveda/colab_val \
  -t 'd4' \
  --val

# %%
# 5. (Opsiyonel) Sonuclari Drive'a kaydet
# !cp -r fig_results/loveda/colab_val /content/drive/MyDrive/DecoupleNet/fig_results/loveda/colab_val
